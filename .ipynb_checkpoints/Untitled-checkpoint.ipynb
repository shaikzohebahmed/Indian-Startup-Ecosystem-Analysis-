# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
df1 = pd.read_csv('startup_funding.csv')

# %%
df1.shape
# Out:
# (3044, 10)

# %%
df1.head()
# Out:
#    Sr No Date dd/mm/yyyy                  Startup Name    Industry Vertical  \
# 0      1      09/01/2020                        BYJU’S               E-Tech
# 1      2      13/01/2020                        Shuttl       Transportation
# 2      3      09/01/2020                     Mamaearth           E-commerce
# 3      4      02/01/2020  https://www.wealthbucket.in/              FinTech
# 4      5      02/01/2020                        Fashor  Fashion and Apparel
#
#                              SubVertical City  Location  \
# 0                             E-learning      Bengaluru
# 1              App based shuttle service        Gurgaon
# 2  Retailer of baby and toddler products      Bengaluru
# 3                      Online Investment      New Delhi
# 4            Embroiled Clothes For Women         Mumbai
#
#               Investors Name       InvestmentnType Amount in USD Remarks
# 0    Tiger Global Management  Private Equity Round  20,00,00,000     NaN
# ...

# %%
df1.tail()
# Out:
#       Sr No Date dd/mm/yyyy      Startup Name Industry Vertical SubVertical  \
# 3039   3040      29/01/2015        Printvenue               NaN         NaN
# 3040   3041      29/01/2015          Graphene               NaN         NaN
# 3041   3042      30/01/2015    Mad Street Den               NaN         NaN
# 3042   3043      30/01/2015         Simplotel               NaN         NaN
# 3043   3044      31/01/2015  couponmachine.in               NaN         NaN
#
#      City  Location                     Investors Name InvestmentnType  \
# 3039            NaN        Asia Pacific Internet Group  Private Equity
# 3040            NaN                     KARSEMVEN Fund  Private Equity
# 3041            NaN     Exfinity Fund, GrowX Ventures.  Private Equity
# 3042            NaN                         MakeMyTrip  Private Equity
# 3043            NaN  UK based Group of Angel Investors    Seed Funding
#
#      Amount in USD                            Remarks
# ...

# %%
# info function gives you the highlevel overview of your dataset
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3044 entries, 0 to 3043
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Sr No              3044 non-null   int64
#  1   Date dd/mm/yyyy    3044 non-null   object
#  2   Startup Name       3044 non-null   object
#  3   Industry Vertical  2873 non-null   object
#  4   SubVertical        2108 non-null   object
#  5   City  Location     2864 non-null   object
#  6   Investors Name     3020 non-null   object
#  7   InvestmentnType    3040 non-null   object
#  8   Amount in USD      2084 non-null   object
#  9   Remarks            419 non-null    object
# dtypes: int64(1), object(9)
# memory usage: 237.9+ KB

# %%
#checking the Null/Missing value in dataset 
df1.isnull().sum()
# Out:
# Sr No                   0
# Date dd/mm/yyyy         0
# Startup Name            0
# Industry Vertical     171
# SubVertical           936
# City  Location        180
# Investors Name         24
# InvestmentnType         4
# Amount in USD         960
# Remarks              2625
# dtype: int64

# %%
sns.heatmap(df1.isnull(),yticklabels=False,cbar=False,cmap="viridis")
# Out:
# <Axes: >

# %%
df1.duplicated().sum()
# Out:
# 0

# %%
df1[df1['Startup Name'].str.lower().str.contains("byju")]
# Out:
#       Sr No Date dd/mm/yyyy          Startup Name  Industry Vertical  \
# 0         1      09/01/2020                BYJU’S             E-Tech
# 67       68      10/07/2019            "BYJU\\'S"             EdTech
# 712     713      25/07/2017  Byju\\xe2\\x80\\x99s  Consumer Internet
# 983     984      29/03/2017  Byju\\xe2\\x80\\x99s  Consumer Internet
# 1164   1165      20/12/2016  BYJU\\xe2\\x80\\x99s  Consumer Internet
# 1356   1357      09/09/2016  Byju\\xe2\\x80\\x99s          Education
# 1880   1881      22/03/2016  Byju\\xe2\\x80\\x99s  Consumer Internet
#
#                             SubVertical City  Location  \
# 0                            E-learning      Bengaluru
# 67                            Education      Bengaluru
# 712                 Mobile Learning App      Bangalore
# 983           Online Education Platform      Bangalore
# 1164           Online Learning platform      Bangalore
# 1356                Online Learning App      Bangalore
# ...

# %%
df1[df1['Investors Name'].str.lower().str.contains("sequoia")==True]
# Out:
#       Sr No Date dd/mm/yyyy      Startup Name Industry Vertical  \
# 2         3      09/01/2020         Mamaearth        E-commerce
# 17       18      13/11/2019        Freshworks          Software
# 35       36      05/09/2019  FPL Technologies           FinTech
# 45       46      01/08/2019           Progcap           Finance
# 68       69      11/07/2019            Moglix        E-Commerce
# ...     ...             ...               ...               ...
# 2974   2975      23/02/2015          HomeLane               NaN
# 2982   2983      25/02/2015         PepperTap               NaN
# 2986   2987      26/02/2015           TinyOwl               NaN
# 2988   2989      27/02/2015           Grofers               NaN
# 3038   3039      28/01/2015     Grabhouse.com               NaN
#
#                                  SubVertical City  Location  \
# 2      Retailer of baby and toddler products      Bengaluru
# 17    Business and customer engagement tools  San Francisco
# ...

# %%
df1['Investors Name'].unique()
# Out:
# array(['Tiger Global Management', 'Susquehanna Growth Equity',
#        'Sequoia Capital India', ..., 'KARSEMVEN Fund',
#        'Exfinity Fund, GrowX Ventures.',
#        'UK based Group of Angel Investors'], dtype=object)

# %%
df1['City  Location'].unique()
# Out:
# array(['Bengaluru', 'Gurgaon', 'New Delhi', 'Mumbai', 'Chennai', 'Pune',
#        'Noida', 'Faridabad', 'San Francisco', 'San Jose,', 'Amritsar',
#        'Delhi', 'Kormangala', 'Tulangan', 'Hyderabad', 'Burnsville',
#        'Menlo Park', 'Gurugram', 'Palo Alto', 'Santa Monica', 'Singapore',
#        'Taramani', 'Andheri', 'Chembur', 'Nairobi', 'Haryana', 'New York',
#        'Karnataka', 'Mumbai/Bengaluru', 'Bhopal',
#        'Bengaluru and Gurugram', 'India/Singapore', 'Jaipur', 'India/US',
#        'Nagpur', 'Indore', 'New York, Bengaluru', 'California', 'India',
#        'Ahemadabad', 'Rourkela', 'Srinagar', 'Bhubneswar', 'Chandigarh',
#        'Delhi & Cambridge', 'Kolkatta', 'Kolkata', 'Coimbatore',
#        'Bangalore', 'Udaipur', nan, 'Ahemdabad', 'Bhubaneswar',
#        'Ahmedabad', 'Surat', 'Goa', 'Uttar Pradesh', 'Nw Delhi', 'Gaya',
#        'Vadodara', 'Trivandrum', 'Missourie', 'Panaji', 'Gwalior',
# ...

# %% [markdown]
# # Issues with the Dataset
#
# **Dirty Data**
# - The date data type is listed as `object` - `Accuracy`
# - Startup names have ambiguous records (e.g., 'flipkart' and 'flipkart.com') - `Accuracy`
# - There are 171 missing values in the Industry Vertical category - `Completion`
# - There are 936 missing values in the Subvertical category; addressing this issue is crucial - `Completion`
# - There are 180 missing values in the City Location column and it is having multiple city names for some records- `Completion`
# - Investors' names have ambiguous records (e.g., 'sequoia' and 'Sequoia Capital India') - `Accuracy`
# - There are 960 missing values in the Amount column - `Completion`
# - There are 2625 missing values in the Remarks column; it might be advisable to consider dropping this column - `Completion`
#
# **Messy Data**
# - Rename all columns for clarity
# - Add an index column labeled as 'Sr No'
# - Convert the Amount values from USD to INR for consistency

# %%
import pandas as pd
import codecs
import re

# Function to clean a string by removing control characters, escape sequences, and multiple spaces
def clean_string(value):
    try:
        decoded_value = value.encode().decode('unicode-escape')  # Convert escape sequences to their corresponding characters
        decoded_value = re.sub(r'[\x00-\x1F]', '', decoded_value)  # Remove control characters
        decoded_value = re.sub(r'\\[xX]..', '', decoded_value)  # Remove remaining escape sequences like \x..
        decoded_value = re.sub(r'\s+', ' ', decoded_value)  # Replace multiple spaces with a single space
        return decoded_value.strip()  # Remove leading and trailing whitespace
    except:
        return value  # Return the original value if decoding fails

# Define the fix_encoding function to clean text data
def fix_encoding(text):
    # Skip URLs
    if re.match(r'^https?://\S+', str(text)):
        return text  # Return the original text if it's a URL
    
    decoded_text = codecs.decode(str(text), 'unicode_escape')  # Convert escape sequences to characters
    cleaned_text = re.sub(r'[^a-zA-Z0-9\s\-\']', '', decoded_text)  # Remove characters that are not letters, digits, spaces, hyphens, or apostrophes
    return cleaned_text  # Return the cleaned text


# Apply the clean_string function element-wise to the entire DataFrame and Create a copy of the cleaned DataFrame
df = df1.applymap(clean_string).copy()

# Iterate through columns and apply fix_encoding only to columns with 'object' (string) dtype
columns = ['Startup Name','Industry Vertical','SubVertical','City  Location']
for col in columns:
    if df[col].dtype == 'object':
        df[col] = df[col].apply(fix_encoding)

# %%
df.drop(columns=['Remarks'],inplace=True)

# %%
df.set_index('Sr No',inplace=True)

# %%
df.rename(columns={
    'Date dd/mm/yyyy':'date',
    'Startup Name':'startup',
    'Industry Vertical':'vertical',
    'SubVertical':'subvertical',
    'City  Location':'city',
    'Investors Name':'investors',
    'InvestmentnType':'round',
    'Amount in USD':'amount'    
    
},inplace=True)

# %%
df.head()
# Out:
#              date                       startup             vertical  \
# Sr No
# 1      09/01/2020                         BYJUS               E-Tech
# 2      13/01/2020                        Shuttl       Transportation
# 3      09/01/2020                     Mamaearth           E-commerce
# 4      02/01/2020  https://www.wealthbucket.in/              FinTech
# 5      02/01/2020                        Fashor  Fashion and Apparel
#
#                                  subvertical       city  \
# Sr No
# 1                                 E-learning  Bengaluru
# 2                  App based shuttle service    Gurgaon
# 3      Retailer of baby and toddler products  Bengaluru
# 4                          Online Investment  New Delhi
# 5                Embroiled Clothes For Women     Mumbai
#
#                        investors                 round        amount
# Sr No
# 1        Tiger Global Management  Private Equity Round  20,00,00,000
# ...

# %%
df.isnull().sum()
# Out:
# date             0
# startup          0
# vertical         0
# subvertical      0
# city             0
# investors       24
# round            4
# amount         960
# dtype: int64

# %% [markdown]
# ## Solving problem with missing data
# - WE CAN FILL THE MISSING NUMERICAL VALUES USING FOLLWING STATISTICAL METHODS-
#
#     - BY MODE OF CENTRAL TENDENCY
#
#      - BACKWARD FILLING
#      - FORWARD FILLING
#
#      - INTERPOLATION(LINEAR)

# %% [markdown]
# ### Cities and Vertical  columns are interpolated  but not with respect to avalaible data
# - replacing missing data with 'NotSpecific' label   and 'Other' respectively

# %%
df['vertical'] = df['vertical'].str.replace('nan','Other')

# %%
df['city']= df['city'].str.replace('nan','Not Specific')

# %%
# filling missing values in investors
df['investors']= df['investors'].fillna('undisclosed')

# %%
# filling missing values in subvertical
df['subvertical']= df['subvertical'].str.replace('nan','Other')

# %%
df.isnull().sum()
# Out:
# date             0
# startup          0
# vertical         0
# subvertical      0
# city             0
# investors        0
# round            4
# amount         960
# dtype: int64

# %%
# Filling missing values in  amount
# 0 means -- undisclosed
df['amount'].fillna('0',inplace=True)


df['amount'] = df['amount'].str.replace(',','')
df['amount'] = df['amount'].str.replace('+','')
df['amount'] = df['amount'].str.replace('N/A','0')
df['amount'] = df['amount'].str.replace('unknown','0')
df['amount'] = df['amount'].str.replace('Undisclosed','0')
df['amount'] = df['amount'].str.replace('undisclosed','0')

# %%
df['amount'] = df['amount'].astype('float')

# %%
def to_inr(dollar):
    inr = dollar * 82.5
    return inr/10000000

# %%
df['amount'] = df['amount'].apply(to_inr)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3044 entries, 1 to 3044
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         3044 non-null   object
#  1   startup      3044 non-null   object
#  2   vertical     3044 non-null   object
#  3   subvertical  3044 non-null   object
#  4   city         3044 non-null   object
#  5   investors    3044 non-null   object
#  6   round        3040 non-null   object
#  7   amount       3044 non-null   float64
# dtypes: float64(1), object(7)
# memory usage: 214.0+ KB

# %%
def rem_err_date(x):#function checks for error in format of date column in funding dataframe
    if re.search('.',x):#data column has formatting errors like '12/052015','13/042015' where backslash (/) is missing or at wrong position
        return x.replace('.','')
    return x

df['date']=df['date'].apply(rem_err_date)#applying user defined funciton to date column using apply() which maps u.d.f to each record of date column
df['date'].replace('12/052015','12/05/2015',inplace=True)
df['date'].replace('01/07/015','01/07/2015',inplace=True)
df['date'].replace('15/012015','15/01/2015',inplace=True)
df['date'].replace('22/01//2015','22/01/2015',inplace=True)
df['date'].replace('13/042015','13/04/2015',inplace=True)
df['date'].replace('05/072018','05/07/2018',inplace=True)
df['date']=pd.to_datetime(df['date'],format='%d/%m/%Y')#d/m/y is the format and to_datetime() is used to convert the datatype of date column to "datetime" from string

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3044 entries, 1 to 3044
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         3044 non-null   datetime64[ns]
#  1   startup      3044 non-null   object
#  2   vertical     3044 non-null   object
#  3   subvertical  3044 non-null   object
#  4   city         3044 non-null   object
#  5   investors    3044 non-null   object
#  6   round        3040 non-null   object
#  7   amount       3044 non-null   float64
# dtypes: datetime64[ns](1), float64(1), object(6)
# memory usage: 214.0+ KB

# %%
df.head()
# Out:
#             date                       startup             vertical  \
# Sr No
# 1     2020-01-09                         BYJUS               E-Tech
# 2     2020-01-13                        Shuttl       Transportation
# 3     2020-01-09                     Mamaearth           E-commerce
# 4     2020-01-02  https://www.wealthbucket.in/              FinTech
# 5     2020-01-02                        Fashor  Fashion and Apparel
#
#                                  subvertical       city  \
# Sr No
# 1                                 E-learning  Bengaluru
# 2                  App based shuttle service    Gurgaon
# 3      Retailer of baby and toddler products  Bengaluru
# 4                          Online Investment  New Delhi
# 5                Embroiled Clothes For Women     Mumbai
#
#                        investors                 round       amount
# Sr No
# 1        Tiger Global Management  Private Equity Round  1650.000000
# ...

# %%
# filling missing values in round
df['round'] = df['round'].fillna('Unknown')

# %% [markdown]
# ### Analysis of data after cleaning
#  - here yellow bars represent the Missing data(NULL values)

# %%
plt.figure(figsize=(10,5))
sns.heatmap(df.isnull(),cmap='viridis',yticklabels=False,cbar=False)
plt.show()

# %% [markdown]
# As we can see below, similar type of values are repeated and hence we'll group them together

# %%
df['round'].unique()
# Out:
# array(['Private Equity Round', 'Series C', 'Series B', 'Pre-series A',
#        'Seed Round', 'Series A', 'Series D', 'Seed', 'Series F',
#        'Series E', 'Debt Funding', 'Series G', 'Series H', 'Venture',
#        'Seed Funding', 'Unknown', 'Funding Round', 'Corporate Round',
#        'Maiden Round', 'pre-series A', 'Seed Funding Round',
#        'Single Venture', 'Venture Round', 'Pre-Series A', 'Angel',
#        'Series J', 'Angel Round', 'pre-Series A',
#        'Venture - Series Unknown', 'Bridge Round', 'Private Equity',
#        'Debt and Preference capital', 'Inhouse Funding',
#        'Seed/ Angel Funding', 'Debt', 'Pre Series A', 'Equity',
#        'Debt-Funding', 'Mezzanine', 'Series B (Extension)',
#        'Equity Based Funding', 'Private Funding', 'Seed / Angel Funding',
#        'Seed/Angel Funding', 'Seed funding', 'Seed / Angle Funding',
#        'Angel / Seed Funding', 'Private', 'Structured Debt', 'Term Loan',
# ...

# %% [markdown]
# Values like "Pre-series A", "Angel", "Seed", etc. are grouped in "Seed"
#
# Similary the following groups are made:
# 1. Seed - "Pre-series A", "Seed Round", "Angel"
# 2. Series A - "Pre-series B", "Series 1"
# 3. Series B
# 4. Series C - "Series C1"
# 5. Series D - "Series D1", "Pre-series E"
# 6. Series E, F, G, H and J were perfect
# 7. Secondary Market
# 8. Bridge - "Bridge Funding", "Bridge Round"
# 9. Debt
# 10. Equity & Debt - "Mezzanine", "M&A"
# 11. Unknown - It consists of values which couldn't tell where they belong

# %%
df['round'] = df['round'].replace(dict.fromkeys(['pre-Series A', 'Angel', 'Pre-Series A ', 'pre-series A', 'Seed ', 'Seed / Angle Funding','Angel Funding','Seed/Angel Funding', 'Angel Round', 'Maiden Round', 'Pre-series A', 'Seed','Seed\\nFunding', 'Seed funding', 'Pre-Series A', 'Seed Round', 'Seed Funding Round', 'Seed / Angel Funding','Angel / Seed Funding', 'pre-Seed', 'Pre Seed', 'Pre Series A', 'Seed Round'], 'Seed'))

# %%
df['round'] = df['round'].replace(dict.fromkeys(['Debt and Preference capital', 'Debt Funding', 'Debt Financing', 'Debt ','Debt', 'Debt-Funding','Structured Debt','Term Loan', 'Crowd funding','Crowd Funding', 'DebtFunding', 'Inhouse Funding'], 'Debt'))

# %%
df['round'] = df['round'].replace(dict.fromkeys(['Series A', 'pre-Series B', 'Series 1'], 'Series A'))

# %%
df['round']= df['round'].replace(dict.fromkeys(['Unknown', 'Venture Series', 'Private','Private Equity','PrivateEquity','Single Venture', 'Equity', 'Private Funding', 'Venture - Series Unknown', 'Venture-Series Unknown', 'Venture', 'Unspecified', 'Venture Round', 'Series', 'Funding', 'Venture ', 'Funding Round','Funding Round ', ' Venture - Series Unknown', 'Corporate Round', 'Equity Based Funding', 'Equity ', 'Private\\nEquity','Private Equity Round', 'Follow-On', 'In Progress'], 'Unknown'))

# %%
df['round'] = df['round'].replace(dict.fromkeys(['Series B', 'Series B (Extension)'], 'Series B'))

# %%
df['round'] = df['round'].replace(dict.fromkeys(['Series C', 'Series C1'], 'Series C'))

# %%
df['round'] = df['round'].replace(dict.fromkeys(['Series D', 'Series D1', 'Pre-series E'], 'Series D'))

# %%
df['round'] = df['round'].replace(dict.fromkeys(['Bridge Funding', 'Bridge Round'], 'Bridge'))

# %%
df['round'] = df['round'].replace(dict.fromkeys(['Equity and Debt ', 'Mezzanine', 'M&A'], 'Equity and Debt'))

# %%
df['round'].unique()
# Out:
# array(['Unknown', 'Series C', 'Series B', 'Seed', 'Series A', 'Series D',
#        'Series F', 'Series E', 'Debt', 'Series G', 'Series H',
#        'Seed Funding', 'Series J', 'Bridge', 'Seed/ Angel Funding',
#        'Equity and Debt'], dtype=object)

# %%
df.head()
# Out:
#             date                       startup             vertical  \
# Sr No
# 1     2020-01-09                         BYJUS               E-Tech
# 2     2020-01-13                        Shuttl       Transportation
# 3     2020-01-09                     Mamaearth           E-commerce
# 4     2020-01-02  https://www.wealthbucket.in/              FinTech
# 5     2020-01-02                        Fashor  Fashion and Apparel
#
#                                  subvertical       city  \
# Sr No
# 1                                 E-learning  Bengaluru
# 2                  App based shuttle service    Gurgaon
# 3      Retailer of baby and toddler products  Bengaluru
# 4                          Online Investment  New Delhi
# 5                Embroiled Clothes For Women     Mumbai
#
#                        investors     round       amount
# Sr No
# 1        Tiger Global Management   Unknown  1650.000000
# 2      Susquehanna Growth Equity  Series C    66.399250
# ...

# %% [markdown]
# **Removing ambigous records(startup names like flipkart and flipkart.com )**

# %%
unique_startup_name=list(df['startup'].unique())
startupname=list(df['startup'])

for i in range(len(unique_startup_name)):
    for j in range(len(startupname)):
        if(re.search(unique_startup_name[i],startupname[j])):
            startupname[j]=unique_startup_name[i].title()
            
df['startup'] = startupname

# %%
df['startup'].value_counts().head(10)
# Out:
# Ola            14
# Healthi        11
# Oyo             9
# Paytm           8
# Swiggy          8
# Lenskart        7
# Digit           7
# Byjus           6
# Lendingkart     6
# Medinfi         6
# Name: startup, dtype: int64

# %%
df['vertical'].unique()
# Out:
# array(['E-Tech', 'Transportation', 'E-commerce', 'FinTech',
#        'Fashion and Apparel', 'Logistics', 'Hospitality', 'Technology',
#        'E-Commerce', 'Aerospace', 'B2B-focused foodtech startup',
#        'FiOtherce', 'Video', 'Gaming', 'Software', 'Health and wellness',
#        'Education', 'Food and Beverage', 'Health and Wellness',
#        'B2B Marketing', 'Video Games', 'SaaS', 'Last Mile Transportation',
#        'Healthcare', 'Customer Service', 'B2B', 'Consumer Goods',
#        'Advertising Marketing', 'IoT', 'Information Technology',
#        'Consumer Technology', 'Accounting', 'Retail',
#        'Customer Service Platform', 'Automotive', 'EdTech', 'Services',
#        'Compliance', 'Transport', 'Artificial Intelligence', 'Tech',
#        'Health Care', 'Luxury Label', 'Waste Management Service',
#        'Deep-Tech', 'Agriculture', 'Energy', 'Digital Media', 'Saas',
#        'Automobile', 'Agtech', 'Social Media', 'Fintech', 'Edtech', 'AI',
# ...

# %% [markdown]
# In "Vertical", the grouping is done as follows:
#
# 1. Education - "Ed-Tech", "Online education", etc.
# 2. Finance - "FinTech", "Financial Services", etc.
# 3. Consumables - "Food-Tech", "Food & Beverages", etc.
# 4. Agriculture - "Agri-Tech", etc.
# 5. Logistics - "Logistic-Tech", "Transport", etc.
# 6. Software - "Saas", "Digital solutions", etc.
# 7. E-Commerce - "Online Marketplace", etc.
# 8. Healthcare & Hospitality - "Health", "Wellness", etc.
# 9. Lifestyle & fashion - "Luxury label", "Personal care", etc.
# 10. Marketing
# 11. Cutting Edge Tech - "AI", "Blockchain", "IoT", etc.
# 12. Gaming & Entertainment
# 13. Energy & Waste Management
# 14. Automobile
# 15. Real Estate
# 16. Compliance
# 17. Retail
# 18. Automobile

# %%
vertical_mapping= {
    "Education": [
        "Education",
        "Multilingual Test Preparation Platform",
        "EduTech",
        "Teacher Empowerment Platform",
        "Edutech",
        "Ed-tech",
        "Online education",
        "Edu Tech",
        "Online School For Analytics Learning",
        "Ed-Tech",
        "Edu-tech",
        "Government Test Preparation Platform",
        "Smart Report Cards For Schools",
        "E-Tech",
        "Edtech",
        "EdTech",
        "Online Education",
    ],
    "Finance": [
        "FinTech",
        "FiOtherce",
        "Digital Analytics Platform",
        "Financial Online Camera and Photo Accessories Retail, Online Gaming Accessories Retail, Online Watches Retail, Online Sunglasses Retail, Online Footwear Retail, Online Bags and Luggage Retail, Online Clothing Retail, Online Sports and Fitness Retail, Online Baby and Kids Retail, Online Pet Supplies Retail, Online Books Retail, Online Automotive Retail, Online Grocery Retail, Online Health and Wellness Retail, Online Travel Retail, Online Jewelry Retail, Online Art and Craft Retail, Online Stationery Services",
        "Financial Services",
        "Financial Services Platform",
        "NBFC",
        "Financial Tech",
        "Financial Inclusion Platform",
        "Finance",
        "BFSI",
        "Fintech",
        "Investment",
        "Rural FinTech",
        "Digital Reconcilation and Financial Services",
        "Accounting",
        "Fin-Tech",
        "Banking Analytics Platform",
        "Nonbanking Finance Company",
    ],
    "Consumables": [
        "Water Purification",
        "Dairy Tech",
        "Healthy Food Manufacturer",
        "Chain Of Tea Cafs",
        "Food Startup",
        "Dairy Based Product Manufacturer",
        "Food-Tech",
        "Consumer Goods Company",
        "Cafe",
        "Food",
        "Online Food Delivery",
        "Food & Beverages",
        "Consumer Goods",
        "Food Delivery",
        "B2B-focused foodtech startup",
        "FoodTech",
        "Food and Beverage",
        "Holiday Resort Chain",
        "Food  Beverages",
        "Food Tech",
    ],
    "Agriculture": [
        "AgriTech",
        "Agriculture",
        "Agri-Tech",
        "AgriTech Startup",
        "Agtech",
    ],
    "Logistics": [
        "Delivery Services",
        "On Demand Laundry Service platform",
        "Hyper-local Logistics",
        "Online Taxi Rental Platform",
        "Cab Sharing service Mobile app",
        "Trucking Logistic Operations",
        "Hyperlocal Shopping App",
        "Supply Chain Management",
        "Utility Solutions Provider",
        "Logistic-Tech",
        "Logistics Solution Provider",
        "Logistics Tech",
        "Truck Aggregator  Logistics service",
        "Logistics",
        "B2B Platform",
        "Transportation",
        "Last Mile Transportation",
        "Express Local Delivery Platform",
        "Transport",
        "Cab Rental Mobile App",
        "Travel Tech",
        "Hyperlocal Delivery Platform",
        "B2B",
        "Hyper-Local Ecommerce",
        "Supply chain ",
        "Cab Booking app platform",
    ],
    "Software": [
        "Saas",
        "Mobile App Testing Platform",
        "Algorithmic Match Making Platform",
        "IT",
        "Consumer Technology",
        "Product Learning platform",
        "Cloud Data Integration Platform",
        "Digital Solutions",
        "Digital  Physical Publishing platform",
        "Big Data  predictive Analysis Platform",
        "Information Technology",
        "Software",
        "Data Analytics Platform",
        "Cloud software solutions",
        "Data Science  UX design Learning platform",
        "Local Mobile Os",
        "Speech Recognition Solutions",
        "Digital solutions",
        "Consumer Internet",
        "Intelligent Data Analytics",
        "Information Technology and Services",
        "Services",
        "Professional Network for Women",
        "Technology Provider",
        "Customer Service Platform",
        "Digital Signal Processing Platform",
        "App Security Testing Platform",
        "Cloud Enterprise Mobility Platform",
        "ECommerce platform solutions",
        "Enterprise Marketing Automation platform",
        "SaaS",
        "Technology",
        "Hyper-Local Ecommerce",
        "API Workflow platform",
    ],
    "E-Commerce": [
        "Mobile Messaging Assistant App",
        "Online Grocery platform",
        "Quick Service Restaurant  Online Delivery",
        "Online Jewellery Etailer",
        "Hyperlocal Shopping App",
        "Qsr Chain",
        "Online content platform for women",
        "ECommerce Website Creation SAAS platform",
        "Product discovery  recommendation platform",
        "SaaS, Ecommerce",
        "Online Shopping Assistant Mobile App",
        "Pre-Used Apparel Shopping Mobile App",
        "Content Discovery  reward points platform",
        "eCommece",
        "Online Bus Cab Ticketing Platform",
        "Online Marketplace",
        "B2B eCommerce Marketplace",
        "Mobile Game development  Design platform",
        "ECommerce",
        "B2B E-commerce",
        "Online  mobile Grocery store",
        "Artificial Intelligence platform",
        "Online Renting platform",
        "Marketplace",
        "Sales  Productivity Software",
        "Personalized Wish List creator app",
        "Real Estate focused Tech platform",
        "E-Commerce",
        "Product Customization Platform",
        "Event Ticketing platform",
        "Mobile App based Loan disbursement platform",
        "E-commerce",
        "Online Car Rental Affiliates",
        "Prepaid Bill manager App",
        "Ecommerce",
        "ecommerce related software product platform",
        "Online Vehicle Spare Parts etailer",
        "Online Meal-Booking Platform For Train Travelers",
        "Mobile Only Shopping Assistant",
        "Mobile accessories online store",
        "Online Meat Ordering Platform",
        "Online Products Discovery Platform",
        "Furniture E-Tailer",
        "eCommerce",
        "Gourmet Food Discovery  Delivery platform",
        "Airfare Marketplace",
        "Reward points mobile app",
    ],
    "Healthcare & Hospitality": [
        "Smart Safety Wearable Devices",
        "Health",
        "Diagnostic Labs Aggregator Platform",
        "Dental Clinic Chain",
        "Digital Healthcare",
        "Mobile Fitness App",
        "Wellness",
        "Online Branded Furniture etailer",
        "Health and Wellness",
        "Doctor Appointment Booking App",
        "Virtual Health consultation app",
        "Health Wellness  Beauty Services App",
        "Online Medical Diagnostic",
        "Health Tech Startup",
        "Hyperlocal healthcare product Delivery Service provider",
        "Health and wellness",
        "Online Health  Wellness platform",
        "Mobile Point Of Sale Solutions",
        "HealthTech",
        "Medical Consultation  Doctor appointment booking platform",
        "On demand cleaning  fixing services",
        "Health Care",
        "Hospitality",
        "Virtual Reality Headset creator",
        "Healthcare",
        "On-Demand Beauty Services",
        "Health-Tech platform",
        "Digital Intelligent learning platform",
        "Mobile Laundry Cleaning Service",
    ],
    "Lifestyle & fashion": [
        "Premium Apparel shopping portal",
        "Fashion and Apparel",
        "Fashion",
        "Designer fashion Jewellery Marketplace",
        "Lifestyle & fashion",
        "Designer Merchandize Marketplace",
        "Branded Budget Hotel Marketplace",
        "Personal care",
        "Fashion Ecommerce",
        "Luxury label",
        "Lifestyle",
        "Fashion Info Aggregator App",
        "Artistic merchandise marketplace",
        "Luxury goods Shopping Platform",
        "Personal Care",
        "Fashion jewelry and accessories e-tailer",
        "Luxury Label",
    ],
    "Marketing": [
        "Advertising",
        "Marketing",
        "Advertising, Marketing",
        "Advertising Marketing",
        "Probiotic Technology Products Manufacturer",
        "Customer Service",
        "Viral Content Web Platform",
        "Intelligent Marketing Cloud",
        "B2B Marketing",
        "Conversational Commerce Mobile App",
    ],
    "Cutting Edge Tech": [
        "Deep-Tech",
        "Block Chain, Cryptocurrency",
        "Blockchain",
        "Deep Tech AI",
        "Nanotechnology",
        "Tech",
        "Machine Learning Platform",
        "AI",
        "IoT",
        "Robotic Program Learning",
        "Artificial Intelligence",
        "Automation",
        "Internet Of Things Platform",
    ],
    "Gaming & Entertainment": [
        "Social Media",
        "OTT Player",
        "Digital Media",
        "Gaming & Entertainment",
        "Video Customer Experience(CX) Platform",
        "Gaming and Entertainment",
        "Entertainment",
        "Social Network",
        "Video",
        "Video Games",
        "Online Gaming",
        "Gaming",
    ],
    "Energy & Waste Management": [
        "Innovative Water Solutions",
        "Waste Management",
        "Energy saving solutions provider",
        "Waste Management Service",
        "Energy",
        "Energy & Waste Management",
    ],
    "Automobile": [
        "Car  Bike ecommerce platform",
        "Automotive Services",
        "Bike Rental Platform",
        "Auto-Tech",
        "Automotive Rental",
        "Self Driven Rental Car Platform",
        "Self-driven vehicle rental",
        "Electric Bike Manufacturers",
        "Auto",
        "Automobile",
        "Automotive",
        "Electric Scooter Manufacturer",
        "Electric Scooter manufacturer",
    ],
    "Real Estate": [
        "Real Estate Broker Platform App",
        "Residential Rental management platform",
        "Real Estate",
        "Property Management Retail, Online Gift Retail, Online Toy Retail, Online Tools and Hardware Retail, Online Kitchen and Dining Retail, Online Garden and Outdoor Retail, Online Office Supplies Retail, Online Party Supplies Retail, Online Fitness Equipment Retail, Online Fashion Accessories Retail, Online Cosmetics Retail, Online Personal Care Retail, Online Home",
        "Real Estate Rating  Analysis",
        "Real Estate Services",
        "Real Estate Advisory",
        "Digital  Mobile Wallet",
        "Real-Time stock data platform",
    ],
    "Compliance": ["Compliance"],
    "Retail": ["Retail"],
}

# %%
for k in vertical_mapping:
    for i in range(len(vertical_mapping[k])):
        for j in range(len(df['vertical'])):
            if(re.search(vertical_mapping[k][i],df['vertical'].iloc[j])):
                df['vertical'].iloc[j]=k.title()

# %%
len(df['vertical'].unique())
# Out:
# 400

# %%
len(df['vertical'].unique())
# Out:
# 400

# %% [markdown]
# Similary "Location" has also been grouped into:
#
# 'Bangalore', 'Mumbai', 'Jaipur', 'Gurgaon',
#        'Delhi', 'Patna', 'Pune', 'Noida', 'Chennai', 'Ahmedabad',
#        'Hyderabad', 'Faridabad', 'Amritsar', 'Haryana', 'Bhopal',
#        'Nagpur', 'Indore', 'Ahemadabad', 'Rourkela' and 'Outside India'

# %%
city_mapping = {
    'Bangalore':['India', 'Karnataka', 'Kormangala', 'New York, Bengaluru', 'Mumbai/Bengaluru', 'Bengaluru and Gurugram', 'Bengaluru ', 'San Francisco/ Bangalore', 'Singapore and Bangalore', 'Bengaluru', 'Bangalore'],
    'Mumbai': ['Andheri', 'Chembur', 'Mumbai'],
    'Outside India':['New York', 'Tulangan', 'Nairobi', 'California', 'India/Singapore', 'India/US', 'Burnsville', 'Menlo Park', 'Palo Alto ', 'Santa Monica',
       'Singapore', 'Taramani', 'San Francisco',
       'San Jose,', 'Wilmington, Delaware, United States',
       'Newark, Delaware, United States of Amercia',
       'Stanford, California, ', 'Washington', 'London', 'Palo Alto'],
    'Jaipur':['Jaipur', 'Jaipur, Rajasthan'],
    'Gurgaon':['Gurgaon','Gurugram'],
    'Ahmedabad':['Ahemadabad'],
    'Delhi': ['Delhi', 'New Delhi', 'New York and Delhi']
}

# %%
len(df['city'].unique())
# Out:
# 108

# %%
for k in city_mapping:
    for i in range(len(city_mapping[k])):
        for j in range(len(df['city'])):
            if(re.search(city_mapping[k][i],df['city'].iloc[j])):
                df['city'].iloc[j]=k.title()

# %%
len(df['city'].unique())
# Out:
# 60

# %%
df.head(10)
# Out:
#             date                       startup                  vertical  \
# Sr No
# 1     2020-01-09                         Byjus                 Education
# 2     2020-01-13                        Shuttl                 Logistics
# 3     2020-01-09                     Mamaearth                E-Commerce
# 4     2020-01-02  Https://Www.Wealthbucket.In/                   Finance
# 5     2020-01-02                        Fashor       Lifestyle & Fashion
# 6     2020-01-13                         Pando                 Logistics
# 7     2020-01-10                        Zomato  Healthcare & Hospitality
# 8     2019-12-12                        Ecozen                  Software
# 9     2019-12-06                      Cardekho                E-Commerce
# 10    2019-12-03                        Dhruva                 Aerospace
#
#                                    subvertical       city  \
# Sr No
# 1                                   E-Learning  Bangalore
# ...

# %%
len(df['startup'].unique())
# Out:
# 2245

# %%
df['startup'].value_counts().sum()
# Out:
# 3044

# %%
df.to_csv('startup_cleaned.csv',index=False)

# %% [markdown]
# ## Investor POV

# %%
df['investors'].unique()
# Out:
# array(['Tiger Global Management', 'Susquehanna Growth Equity',
#        'Sequoia Capital India', ..., 'KARSEMVEN Fund',
#        'Exfinity Fund, GrowX Ventures.',
#        'UK based Group of Angel Investors'], dtype=object)

# %%
# list of investors
sorted(set(df['investors'].str.split(',').sum()))
# Out:
# ['',
#  ' & Others',
#  ' & other Angel investors.',
#  ' 100 Co-founders Lab and others.',
#  ' 122 West Ventures',
#  ' 1Crowd',
#  ' 3ONE4 Capital Advisors',
#  ' 3one4 Capital',
#  ' 3one4 Capital Advisors LLP',
#  ' 500 Start-Ups',
#  ' 500 Startups',
#  ' 500 Startups & Other HNIs',
#  ' 50K Ventures & others',
#  ' 91SpringBoard',
#  ' 91springboard',
#  ' ABB Technology Ventures',
#  ' ABCOM Investments',
#  ' AECAL',
#  ' AET Fund',
#  ' AL Nour International Holdings and Mark V Investments',
#  ' ASP Consulting',
#  ' AVN Business Solutions',
#  ' Aarin Capital',
#  ' Aarin Capital & Others',
#  ' Aaruha Technology Fund',
#  ' Abaran Deep',
#  ' Abhai S. Rao',
#  ' Abhay Singhal',
#  ' Abhijit Bhandari',
#  ' Abhinav Patodia',
#  ' Abhinav Sinha',
#  ' Abhishek Acharya',
#  ' Abhishek Goyal',
#  ' Abhishek Gupta',
#  ' Abhishek Jain',
#  ' Abhishekh Goyal',
#  ' Abstract Ventures',
#  ' Abu Farhan Azmi',
#  ' Accel',
#  ' Accel India',
#  ' Accel Partner',
# ...

# %%
# Recent Investments
df[df['investors'].str.contains(' IDG Ventures')].head()[['date','startup','vertical','city','round','amount']]
# Out:
#             date  startup                vertical       city     round  \
# Sr No
# 102   2019-04-13  Tripoto  Gaming & Entertainment  New Delhi  Series B
# 259   2018-05-02  Bizongo                Software     Mumbai   Unknown
# 310   2018-04-26    Popxo                Software      Delhi   Unknown
# 505   2017-11-21   Heckyl                Software     Mumbai   Unknown
# 528   2017-10-05   Little                Software  New Delhi   Unknown
#
#            amount
# Sr No
# 102     29.628844
# 259    181.500000
# 310     45.375000
# 505     22.275000
# 528      8.250000

# %%
# Biggest investments
df[df['investors'].str.contains(' IDG Ventures')].groupby('startup')['amount'].sum().sort_values(ascending=False).head(8)
# Out:
# startup
# Lenskart      512.7375
# Curefit       330.0000
# Bizongo       181.5000
# Vserv         123.7500
# Xpressbees    103.1250
# Firstcry       82.5000
# Popxo          70.9500
# Aasaanjobs     53.6250
# Name: amount, dtype: float64

# %%
df[df['investors'].str.contains(' IDG Ventures')].groupby('vertical')['amount'].sum()
# Out:
# vertical
# CRM  Analytics platform              8.250000
# E-Commerce                         680.625000
# Gaming & Entertainment              29.628844
# Other                              153.862500
# Software                           850.575000
# global community for travellers      0.000000
# Name: amount, dtype: float64

# %%
# sector ->pie
df[df['investors'].str.contains(' IDG Ventures')].groupby('vertical')['amount'].sum().plot(kind='pie')
# Out:
# <Axes: ylabel='amount'>

# %%
# stage ->pie
df[df['investors'].str.contains(' IDG Ventures')].groupby('round')['amount'].sum().plot(kind='pie')
# Out:
# <Axes: ylabel='amount'>

# %%
# city ->pie
df[df['investors'].str.contains(' IDG Ventures')].groupby('city')['amount'].sum().plot(kind='pie')
# Out:
# <Axes: ylabel='amount'>

# %%
df['year'] = df['date'].dt.year
df['month'] = df['date'].dt.month

# %%
# YoY investment graph
df[df['investors'].str.contains(' IDG Ventures')].groupby(['year','month'])['amount'].sum().plot()
# Out:
# <Axes: xlabel='year,month'>

# %%
# Similar Investors
df[df['investors'].str.contains(' IDG Ventures')]
# Out:
#             date                startup                         vertical  \
# Sr No
# 102   2019-04-13                Tripoto           Gaming & Entertainment
# 259   2018-05-02                Bizongo                         Software
# 310   2018-04-26                  Popxo                         Software
# 505   2017-11-21                 Heckyl                         Software
# 528   2017-10-05                 Little                         Software
# 673   2017-08-29                Curefit                         Software
# 964   2017-03-16                  Popxo                         Software
# 1012  2017-02-13               Sigtuple                         Software
# 1211  2016-11-14               Activeai                         Software
# 1215  2016-11-15             Playsimple                         Software
# 1395  2016-09-23            Cloudcherry                         Software
# 1506  2016-07-04                Curefit                         Software
# ...

# %% [markdown]
# # Company POV

# %%
# list of startup
print(sorted(list(df['startup'].unique())))
# Out:
# ['121Policy', '19Th Mile', '1Crowd', '1Mg', '20Dresses', '33Coupons', '360Ride', '3Dexter', '3Hcare', '3Rdflix', '48East', '4Tigo', '5Th Vital', '6Degree', '75F', '91Springboard', '99Games', '99Perhour', '9Stacks', 'Aadharapicom', 'Aadyah', 'Aagaarcom', 'Aahaa', 'Aarav Uav', 'Aasaanjobs', 'Aashiyaan', 'Aavishkaar-Intellecap Group', 'Aberuk', 'Abhibus', 'Abi Health', 'Absentia', 'Ace Turtle', 'Ace2Three', 'Acko', 'Actionable Analytics', 'Active Ai', 'Activeai', 'Actofit', 'Actonmagic', 'Ad2Pro', 'Address Health', 'Admitkard', 'Adpushup', 'Adstringo', 'Adurcup', 'Advanced Structures India', 'Advantage Club', 'Advenio', 'Adwyze', 'Adytude', 'Aeon Learning', 'Aequm', 'Aermed', 'Affimity', 'Affordplan', 'Agara Labs', 'Agentdesks', 'Agricxlab', 'Agrostar', 'Agrowave', 'Aha Taxis', 'Aircto', 'Airmed Labs', 'Airpay', 'Airwood', 'Airzaar', 'Aisle', 'Akosha', 'Alef\nMobitech', 'Allizhealth', 'Allygrow Technologies', 'Almaconnect', 'Almamapper', 'Alpha Capital', 'Alteria Capital', 'Alternacare'
# ...

# %%
df['startup'] = df['startup'].str.replace("Byju'S",'Byjus')

# %%
# Industry
df[df['startup'].str.contains("Byjus")]['vertical'].value_counts()
# Out:
# Software     4
# Education    3
# Name: vertical, dtype: int64

# %%
df[df['startup'].str.contains("Byjus")].groupby(['vertical'])['amount'].sum()
# Out:
# vertical
# Education    3300.00
# Software     1031.25
# Name: amount, dtype: float64

# %%
# Subindustry

df[df['startup'].str.contains("Byjus")]['subvertical'].value_counts()
# Out:
# E-Learning                           1
# Education                            1
# Mobile Learning App                  1
# Online Education Platform            1
# Online Learning Platform             1
# Online Learning App                  1
# Educational Video Content Creator    1
# Name: subvertical, dtype: int64

# %%
df['subvertical'] = df['subvertical'].str.replace("Online Eyewear eTailer",'Online Eyewear Retailer')
df['subvertical'] = df['subvertical'].str.replace("Eyewear Etailing Platform",'Eyewear Retailing Platform')
df['subvertical'] = df['subvertical'].str.title()

# %%
df[df['startup'].str.contains("Lenskart")]['subvertical'].value_counts()
# Out:
# Online Eyewear Retailer           3
# Online Eyewear Shopping Portal    1
# Eyewear  Accessories Etailer      1
# Eyewear Retailing Platform        1
# Other                             1
# Name: subvertical, dtype: int64

# %%
# Location
df[df['startup'].str.contains("Lenskart")]['city'].value_counts()
# Out:
# New Delhi       3
# Faridabad       2
# Bangalore       1
# Not Specific    1
# Name: city, dtype: int64

# %%
df[df['startup'].str.contains("Byjus")]['city'].value_counts()
# Out:
# Bangalore    5
# Bengaluru    2
# Name: city, dtype: int64

# %%
# Funding Rounds
df[df['startup'].str.contains("Byjus")]['round'].value_counts()
# Out:
# Unknown    7
# Name: round, dtype: int64

# %%
df[df['startup'].str.contains("Lenskart")]['round'].value_counts()
# Out:
# Unknown     6
# Series G    1
# Name: round, dtype: int64

# %%
df
# Out:
#             date                       startup             vertical  \
# Sr No
# 1     2020-01-09                         Byjus            Education
# 2     2020-01-13                        Shuttl            Logistics
# 3     2020-01-09                     Mamaearth           E-Commerce
# 4     2020-01-02  Https://Www.Wealthbucket.In/              Finance
# 5     2020-01-02                        Fashor  Lifestyle & Fashion
# ...          ...                           ...                  ...
# 3040  2015-01-29                    Printvenue                Other
# 3041  2015-01-29                      Graphene                Other
# 3042  2015-01-30                Mad Street Den                Other
# 3043  2015-01-30                     Simplotel                Other
# 3044  2015-01-31               Couponmachinein                Other
#
#                                  subvertical          city  \
# Sr No
# 1                                 E-Learning     Bengaluru
# ...

# %%
df[df['startup'].str.contains("Byjus")].groupby(['investors','round','year'])['amount'].sum().reset_index()
# Out:
#                                            investors    round  year   amount
# 0  Chan Zuckerberg Initiative, Times Internet Ltd...  Unknown  2016   412.50
# 1                International Financial Corporation  Unknown  2016   123.75
# 2                         Qatar Investment Authority  Unknown  2019  1237.50
# 3                              Sequoia India, Sofina  Unknown  2016   618.75
# 4                                   Tencent Holdings  Unknown  2017   288.75
# 5                            Tiger Global Management  Unknown  2020  1650.00
# 6                                         Verlinvest  Unknown  2017     0.00

# %%
df[df['startup'].str.contains("Ola")].groupby(['investors','round','year'])['amount'].sum().sort_values(ascending=False).reset_index().sort_values(by='year')
# Out:
#                                             investors     round  year  \
# 0   Baillie Gifford, Falcon Edge Capital, Tiger Gl...   Unknown  2015
# 1   DST Global, Steadview Capital, Tiger Global, A...   Unknown  2015
# 4   Falcon Edge Capital, NY based Hedge Fund, Tige...   Unknown  2015
# 9                                         Didi Kuaidi   Unknown  2015
# 12                                         Ratan Tata   Unknown  2015
# 2                                 SoftBank Group Corp   Unknown  2017
# 3                                    SIMI Pacific Pte   Unknown  2017
# 5                             Tencent, Softbank Group   Unknown  2017
# 6               Falcon Edge Capital, Capital Advisers   Unknown  2017
# 7                        Tekne Capital Management LLC   Unknown  2017
# 8                            Tekne Capital Management   Unknown  2017
# 10                          ANI Technologies Pvt. Ltd   Unknown  2017
# ...

# %% [markdown]
# # General Analysis

# %%
# MoM chart -> Total + Count
df.groupby(['year','month'])['amount'].sum().plot()
# Out:
# <Axes: xlabel='year,month'>

# %%
df.groupby(['year','month'])['amount'].count().plot()
# Out:
# <Axes: xlabel='year,month'>

# %%
# Total funded startups
df[df['startup'].str.contains("Byjus")]['amount'].sum()
# Out:
# 4331.25

# %%
df['amount'].mean()
# Out:
# 103.37953272989981

# %%
df['amount'].sum()
# Out:
# 314687.297629815

# %%
df['amount'].max()
# Out:
# 32175.0

# %%
# Sector Analysis Pie -> top sectors(Count + Sum) 
df.groupby('vertical')['amount'].sum().sort_values(ascending=False).head(5)
# Out:
# vertical
# E-Commerce    88207.017463
# Software      78526.817944
# Logistics     48566.804501
# Finance       28663.373186
# Other         10162.443786
# Name: amount, dtype: float64

# %%
# Type of funding
df.groupby('round')['amount'].sum().sort_values(ascending=False).head(5)
# Out:
# round
# Unknown         237631.562646
# Series B         39642.864814
# Series D         12224.841750
# Series C          8618.926751
# Seed Funding      4701.784791
# Name: amount, dtype: float64

# %%
# City wise funding
df.groupby('city')['amount'].sum().sort_values(ascending=False).head(5)
# Out:
# city
# Bangalore        158425.103620
# Mumbai            40902.218115
# Gurgaon           31994.437675
# Delhi             27809.689999
# Outside India     12304.619536
# Name: amount, dtype: float64

# %%
# Top Startups -> year wise -> Overall
df.groupby(['year','startup'])['amount'].sum().sort_values(ascending=False).reset_index()\
.drop_duplicates(subset='year',keep='first').sort_values(by='year')
# Out:
#     year     startup     amount
# 3   2015         Ola   9528.750
# 29  2016    Snapdeal   1650.000
# 0   2017    Flipkart  33080.025
# 8   2018  True North   4950.000
# 1   2019      Rapido  32175.000
# 26  2020       Byjus   1650.000

# %%
df.head()
# Out:
#             date                       startup             vertical  \
# Sr No
# 1     2020-01-09                         Byjus            Education
# 2     2020-01-13                        Shuttl            Logistics
# 3     2020-01-09                     Mamaearth           E-Commerce
# 4     2020-01-02  Https://Www.Wealthbucket.In/              Finance
# 5     2020-01-02                        Fashor  Lifestyle & Fashion
#
#                                  subvertical       city  \
# Sr No
# 1                                 E-Learning  Bangalore
# 2                  App Based Shuttle Service    Gurgaon
# 3      Retailer Of Baby And Toddler Products  Bangalore
# 4                          Online Investment      Delhi
# 5                Embroiled Clothes For Women     Mumbai
#
#                        investors     round       amount  year  month
# Sr No
# 1        Tiger Global Management   Unknown  1650.000000  2020      1
# ...

# %%
investors_list = []
for _,row in df.iterrows():
    for investor in df['investors'].str.split(','):
        for i in investor:
            investors_list.append({
                'date' : row['date'],
                'startup': row['startup'],
                'vertical' : row['vertical'],
                'subvertical' : row['subvertical'],
                'city' : row['city'],
                'investors' :investor,
                'amount' : row['amount'],
                'year' : row['year'],
                'month' : row['month']
            })
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[197], line 9
#       3 for investor in df['investors'].str.split(','):
#       4     for i in investor:
#       5         investors_list.append({
#       6             'date' : row['date'],
#       7             'startup': row['startup'],
#       8             'vertical' : row['vertical'],
# ----> 9             'subvertical' : row['subvertical'],
#      10             'city' : row['city'],
#      11             'investors' :investor,
#      12             'amount' : row['amount'],
#      13             'year' : row['year'],
#      14             'month' : row['month']
#      15         })
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:981, in Series.__getitem__(self, key)
#     978     return self._values[key]
#     980 elif key_is_scalar:
# --> 981     return self._get_value(key)
# ...

# %%
investors_list
# Out:
# [{'date': Timestamp('2020-01-09 00:00:00'),
#   'startup': 'Byjus',
#   'vertical': 'Education',
#   'subvertical': 'E-Learning',
#   'city': 'Bangalore',
#   'investors': ['Tiger Global Management'],
#   'amount': 1650.0,
#   'year': 2020,
#   'month': 1},
#  {'date': Timestamp('2020-01-09 00:00:00'),
#   'startup': 'Byjus',
#   'vertical': 'Education',
#   'subvertical': 'E-Learning',
#   'city': 'Bangalore',
#   'investors': ['Susquehanna Growth Equity'],
#   'amount': 1650.0,
#   'year': 2020,
#   'month': 1},
#  {'date': Timestamp('2020-01-09 00:00:00'),
#   'startup': 'Byjus',
#   'vertical': 'Education',
#   'subvertical': 'E-Learning',
#   'city': 'Bangalore',
#   'investors': ['Sequoia Capital India'],
#   'amount': 1650.0,
#   'year': 2020,
#   'month': 1},
#  {'date': Timestamp('2020-01-09 00:00:00'),
#   'startup': 'Byjus',
#   'vertical': 'Education',
#   'subvertical': 'E-Learning',
#   'city': 'Bangalore',
#   'investors': ['Vinod Khatumal'],
#   'amount': 1650.0,
# ...

# %%
new_df = pd.DataFrame(investors_list)
# Out:
# KeyboardInterrupt

# %%
new_df
# Out:
#         date          startup vertical subvertical          city  \
# 0 2015-01-31  Couponmachinein    Other       Other  Not Specific
#
#                            investors  amount  year  month
# 0  UK based Group of Angel Investors   1.155  2015      1

# %%
# Top investors
df.groupby
